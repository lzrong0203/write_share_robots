# %%
url = "https://www.twse.com.tw/rwd/zh/afterTrading/STOCK_DAY_AVG?date=20230101&stockNo=2330&response=csv"

# %%
import pandas as pd

# %%
pd.read_csv(url, encoding="big5", skiprows=1, skipfooter=5)
# Out:
# /var/folders/wz/nykyh5gs2ydchhm_zdd_mkth0000gn/T/ipykernel_88936/740135055.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   pd.read_csv(url, encoding="big5", skiprows=1, skipfooter=5)
#            日期     收盤價  Unnamed: 2
# 0   112/01/03  453.00         NaN
# 1   112/01/04  449.50         NaN
# 2   112/01/05  458.50         NaN
# 3   112/01/06  458.50         NaN
# 4   112/01/09  481.00         NaN
# 5   112/01/10  486.00         NaN
# 6   112/01/11  484.50         NaN
# 7   112/01/12  486.50         NaN
# 8   112/01/13  500.00         NaN
# 9   112/01/16  505.00         NaN
# 10  112/01/17  503.00         NaN
# 11  112/01/30  543.00         NaN
# 12  112/01/31  522.00         NaN
# 13     月平均收盤價  486.96         NaN

# %%
park_data = pd.read_csv("/Users/lzrong/Downloads/臺北捷運車站周邊轉乘停車場資訊.csv",
                        encoding="big5", index_col="項次")

# %%
park_data
# Out:
#                停車場名稱         緯度           經度  小汽車   機車  自行車
# 項次
# 1        捷運劍南路站轉乘停車場  25.084540  121.5544513  282   52  122
# 2         捷運文德站轉乘停車場  25.078450   121.584945  306    0    0
# 3         捷運頂埔站轉乘停車場  24.958923  121.4200616   77  298    0
# 4         捷運永寧站轉乘停車場  24.965650    121.43562  202    0    0
# 5         捷運海山站轉乘停車場  24.986950   121.449236   63   99  132
# ..               ...        ...          ...  ...  ...  ...
# 219      捷運幸福站自行車停車區  25.049670    121.46042    0    0  227
# 220   捷運新北產業園區站轉乘停車場  25.060600    121.45964   25    0    0
# 221  捷運新北產業園區站自行車停車區  25.060780    121.45952    0    0   91
# 222       捷運新莊站機車停車區  25.036145  121.4525961    0    2    0
# 223       捷運辛亥站機車停車區  25.005520    121.55709    0   18    0
#
# [223 rows x 6 columns]

# %%
youbike_url = "https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json"

# %%
youbike_df = pd.read_json(youbike_url)

# %%
youbike_df.set_index("sno")
# Out:
#                                 sna  tot  sbi   sarea                 mday  \
# sno
# 500101001        YouBike2.0_捷運科技大樓站   28    9     大安區  2024-01-08 00:57:05
# 500101002    YouBike2.0_復興南路二段273號前   21    8     大安區  2024-01-08 00:57:05
# 500101003      YouBike2.0_國北教大實小東側門   16    9     大安區  2024-01-08 00:57:05
# 500101004         YouBike2.0_和平公園東側   11    4     大安區  2024-01-08 00:57:05
# 500101005      YouBike2.0_辛亥復興路口西北側   16    1     大安區  2024-01-08 00:57:05
# ...                             ...  ...  ...     ...                  ...
# 500119087      YouBike2.0_臺大總圖書館西南側   30   17  臺大公館校區  2024-01-08 00:57:16
# 500119088        YouBike2.0_臺大黑森林西側   20    4  臺大公館校區  2024-01-08 00:57:16
# 500119089        YouBike2.0_臺大獸醫館南側   24   11  臺大公館校區  2024-01-08 00:57:16
# 500119090      YouBike2.0_臺大新體育館東南側   40    3  臺大公館校區  2024-01-08 00:57:16
# 500119091  YouBike2.0_臺大明達館北側(員工宿舍)   18   14  臺大公館校區  2024-01-08 00:57:16
#
#                 lat        lng             ar     sareaen  \
# ...

# %%
park_data.head()
# Out:
#           停車場名稱         緯度           經度  小汽車   機車  自行車
# 項次
# 1   捷運劍南路站轉乘停車場  25.084540  121.5544513  282   52  122
# 2    捷運文德站轉乘停車場  25.078450   121.584945  306    0    0
# 3    捷運頂埔站轉乘停車場  24.958923  121.4200616   77  298    0
# 4    捷運永寧站轉乘停車場  24.965650    121.43562  202    0    0
# 5    捷運海山站轉乘停車場  24.986950   121.449236   63   99  132

# %%
park_data.tail()
# Out:
#                停車場名稱         緯度           經度  小汽車  機車  自行車
# 項次
# 219      捷運幸福站自行車停車區  25.049670    121.46042    0   0  227
# 220   捷運新北產業園區站轉乘停車場  25.060600    121.45964   25   0    0
# 221  捷運新北產業園區站自行車停車區  25.060780    121.45952    0   0   91
# 222       捷運新莊站機車停車區  25.036145  121.4525961    0   2    0
# 223       捷運辛亥站機車停車區  25.005520    121.55709    0  18    0

# %%
park_data["經度"][park_data["經度"].str.contains(",")] = 121.47214
# Out:
# /var/folders/wz/nykyh5gs2ydchhm_zdd_mkth0000gn/T/ipykernel_88936/409200906.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   park_data["經度"][park_data["經度"].str.contains(",")] = 121.47214

# %%
park_data["經度"][50]
# Out:
# 121.47214

# %%
park_data["經度"] = pd.to_numeric(park_data["經度"])

# %%
park_data.dtypes
# Out:
# 停車場名稱     object
# 緯度       float64
# 經度       float64
# 小汽車        int64
# 機車         int64
# 自行車        int64
# dtype: object

# %%
park_data.describe(include="object")
# Out:
#              停車場名稱
# count          223
# unique         139
# top     捷運輔大站機車停車區
# freq             6

# %%
youbike_df.describe(include="object")
# Out:
#                        sna sarea                 mday        ar     sareaen  \
# count                 1328  1328                 1328      1328        1328
# unique                1328    13                    2      1327          13
# top     YouBike2.0_捷運科技大樓站   大安區  2024-01-08 00:57:16  酒泉街235號前  Daan Dist.
# freq                     1   171                 1282         2         171
#
#                                                     snaen  \
# count                                                1328
# unique                                               1322
# top     YouBike2.0_Xinhu 3rd Rd. & Ln. 146， Xinhu 2nd ...
# freq                                                    2
#
#                                 aren        srcUpdateTime  \
# count                           1328                 1328
# unique                          1324                    1
# top     No. 259， Daye Rd. (Opposite)  2024-01-08 00:57:40
# ...
